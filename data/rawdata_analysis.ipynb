# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
dataset = pd.read_csv("Python Programming Questions Dataset.csv")

# %%
dataset
# Out:
#                                              Instruction  \
# 0      Write a function to find squares of individual...
# 1      Create a function in Python which takes a list...
# 2      Design a function in Python that sorts a list ...
# 3      Develop a greedy strategy in Python to find th...
# 4      Write a Python program to create a singly link...
# ...                                                  ...
# 13104  Create a web scraper in Python that loads a we...
# 13105  Design an algorithm in Python for finding and ...
# 13106  Write a Python program to count words in a sen...
# 13107  Write a python program to print the following ...
# 13108  Create a webhook in Python to handle incoming ...
#
#                                                    Input  \
# 0                                                    NaN
# 1                                              [3, 4, 5]
# 2                             ['red', 'green', 'orange']
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13104  URL: https://www.example.com/\nText to extract...
# 13105                                                100
# 13106  Sentence: “The quick brown fox jumps over the ...
# 13107                                              n = 5
# 13108  {\n  "name": "John Doe",\n  "email": "john@exa...
#
#                                                   Output
# 0      def square_nums(nums):\r\n square_nums = list(...
# 1      def sum_squares(nums):\n    result = 0\n    fo...
# 2      def sort_list_alphabetically(input_list): \n  ...
# 3      def min_cost(points):\n    points.sort()  # so...
# 4      class Node():\n  def __init__(self, data):\n  ...
# ...                                                  ...
# 13104  import requests\nfrom bs4 import BeautifulSoup...
# 13105  def find_all_primes(n): \n  for num in range(2...
# 13106  sentence = "The quick brown fox jumps over the...
# 13107  def pattern(n):\n  # Outer loop \n    for i in...
# 13108  import json\nfrom flask import Flask, request\...
#
# [13109 rows x 3 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13109 entries, 0 to 13108
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Instruction  13109 non-null  object
#  1   Input        7560 non-null   object
#  2   Output       13109 non-null  object
# dtypes: object(3)
# memory usage: 307.4+ KB

# %%
def print_questions_answers10(dataset):
    for index, row in dataset.head(10).iterrows():
        print(f"Instruction: {row['Instruction']}")
        print(f"Correct Answer:\n{row['Output']}")
        print("-" * 50)

print_questions_answers10(dataset)
# Out:
# Instruction: Write a function to find squares of individual elements in a list using lambda function.
# Correct Answer:
# def square_nums(nums):
#  square_nums = list(map(lambda x: x ** 2, nums))
#  return square_nums
# --------------------------------------------------
# Instruction: Create a function in Python which takes a list of numbers and returns the sum of squares of those numbers.
# Correct Answer:
# def sum_squares(nums):
#     result = 0
#     for num in nums:
#         result += num*num
#
#     return result
#
# nums = [3, 4, 5]
#
# result = sum_squares(nums)
# print(result)
# --------------------------------------------------
# Instruction: Design a function in Python that sorts a list of strings in alphabetical order.
# Correct Answer:
# def sort_list_alphabetically(input_list):
#     output_list = sorted(input_list)
#     return output_list
#
# input_list = ['red', 'green', 'orange']
# sorted_list = sort_list_alphabetically(input_list)
# print("Sorted List in Alphabetical Order:", sorted_list)
# --------------------------------------------------
# Instruction: Develop a greedy strategy in Python to find the minimum total cost of connecting n given points on a 2D plane using minimum number of lines.
# Correct Answer:
# def min_cost(points):
#     points.sort()  # sort the points by their x-coordinate
#     total_cost = 0  # initial cost
#     for i in range(len(points)-1):
#         cost = abs(points[i+1][1] - points[i][1])  # calculate the cost of connecting two successive points
#         total_cost += cost  # add to the total cost
#     return total_cost
# --------------------------------------------------
# Instruction: Write a Python program to create a singly linked list
# Correct Answer:
# class Node():
#   def __init__(self, data):
#     self.data = data
#     self.next = None
#
# class List():
#   def __init__(self):
#     self.head = None
#
#   def addNode(self, data):
#     node = Node(data)
#     if self.head == None:
#        self.head = node
#     else:
#       current = self.head
#       while current.next != None:
#         current = current.next
#       current.next = node
# --------------------------------------------------
# Instruction: GPT-model, create a Python program for shuffeling the elements of an array.
# Correct Answer:
# import random
#
# def shuffle(arr):
#   for i in range(len(arr)):
#     j = random.randint(0, len(arr)-1)
#     arr[i], arr[j] = arr[j], arr[i]
#
#   return arr
# --------------------------------------------------
# Instruction: Edit the following Python code such that it will print an array containing the seven days of the week.
# Correct Answer:
# days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
#
# for day in days:
#     print(day)
# --------------------------------------------------
# Instruction: Create a calculator program using Python.
# Correct Answer:
# def calculator(num1, num2, op):
#  if op == '+':
#  return num1 + num2
#  elif op == '-':
#  return num1 - num2
#  elif op == '*':
#  return num1 * num2
#  elif op == '/':
#  return num1 / num2
#  else:
#  return None
# --------------------------------------------------
# Instruction: Develop a Python script that takes two parameters and prints the greatest out of them.
# Correct Answer:
# def find_greatest(param1, param2):
#   if param1 > param2:
#       greater = param1
#   else:
#       greater = param2
#   return greater
# --------------------------------------------------
# Instruction: Create a Python program that prints the Roman numerals representation for any given number.
# Correct Answer:
# def Roman(number):
#  roman = {1000: 'M', 900: 'CM', 500: 'D', 400: 'CD',
# 100: 'C', 90: 'XC', 50: 'L', 40: 'XL',
#  10: 'X', 9: 'IX', 5: 'V', 4: 'IV', 1: 'I'}
#  result = ''
#
#  for num in roman.keys():
#  while number >= num:
#  result += roman[num]
#  number -= num
#
#  print (result)
#
# number = int(input('Enter a number: '))
# Roman(number)
# --------------------------------------------------

# %%
def count_nonempty_lines(output_text):
    if pd.isna(output_text):
        return 0
    return sum(1 for line in output_text.split('\n') if line.strip())
    #return len(output_text.split('\n'))

def create_line_count_distribution(dataset):
    # Spočítanie neprázdnych riadkov pre každú odpoveď
    line_counts = dataset['Output'].apply(count_nonempty_lines)
    
    # Vytvorenie distribúcie (počítadlo výskytov)
    distribution = Counter(line_counts)
    
    # Vizualizácia histogramu
    plt.figure(figsize=(10, 6))
    plt.bar(distribution.keys(), distribution.values(), width=0.8)
    plt.title("Distribúcia odpovedí podľa počtu neprázdnych riadkov")
    plt.xlabel("Počet neprázdnych riadkov v odpovedi")
    plt.ylabel("Počet výskytov")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
    
    return distribution

# Spustenie analýzy
distribution = create_line_count_distribution(dataset)

print("Distribúcia výskytov odpovedí podľa počtu neprázdnych riadkov:")
for line_count, count in sorted(distribution.items()):
    print(f"{line_count} riadkov: {count} odpovedí")
# Out:
# Distribúcia výskytov odpovedí podľa počtu neprázdnych riadkov:
# 1 riadkov: 426 odpovedí
# 2 riadkov: 954 odpovedí
# 3 riadkov: 1140 odpovedí
# 4 riadkov: 1057 odpovedí
# 5 riadkov: 1501 odpovedí
# 6 riadkov: 1404 odpovedí
# 7 riadkov: 1445 odpovedí
# 8 riadkov: 1347 odpovedí
# 9 riadkov: 1071 odpovedí
# 10 riadkov: 819 odpovedí
# 11 riadkov: 655 odpovedí
# 12 riadkov: 496 odpovedí
# 13 riadkov: 315 odpovedí
# 14 riadkov: 195 odpovedí
# 15 riadkov: 112 odpovedí
# 16 riadkov: 80 odpovedí
# 17 riadkov: 55 odpovedí
# 18 riadkov: 19 odpovedí
# 19 riadkov: 10 odpovedí
# 20 riadkov: 2 odpovedí
# 21 riadkov: 1 odpovedí
# 22 riadkov: 3 odpovedí
# 26 riadkov: 1 odpovedí
# 38 riadkov: 1 odpovedí

# %%
def questions_with_long_outputs(dataset, min_lines=15):
    # Filtrujeme otázky podľa počtu neprázdnych riadkov v odpovedi
    for index, row in dataset.iterrows():
        output_text = row['Output']
        if pd.notna(output_text):
            line_count = sum(1 for line in output_text.split('\n') if line.strip())
            if line_count > min_lines:
                print(f"Otázka (Instruction):\n{row['Instruction']}")
                print(f"Počet neprázdnych riadkov: {line_count}")
                print("-" * 50)

# %%
questions_with_long_outputs(dataset, min_lines=20)
# Out:
# Otázka (Instruction):
# Generate a python program to convert numbers in between 1 to 10 to their respective word form.
# Počet neprázdnych riadkov: 21
# --------------------------------------------------
# Otázka (Instruction):
# Create a program in Python for converting an integer number to a Roman numeral.
# Počet neprázdnych riadkov: 22
# --------------------------------------------------
# Otázka (Instruction):
# Write a function to find kth element from the given two sorted arrays.
# Počet neprázdnych riadkov: 22
# --------------------------------------------------
# Otázka (Instruction):
# Create a data structure in JavaScript to represent a directory structure.
# Počet neprázdnych riadkov: 22
# --------------------------------------------------
# Otázka (Instruction):
# Implement a Python program to print all numbers from 0 to 100 that are multiples of 3.
# Počet neprázdnych riadkov: 38
# --------------------------------------------------
# Otázka (Instruction):
# Create a simple web page using HTML and CSS to display a list of the top 5 most popular programming languages.
# Počet neprázdnych riadkov: 26
# --------------------------------------------------
