# %%
import pandas as pd
from difflib import SequenceMatcher
import os
import matplotlib.pyplot as plt
from collections import Counter

# %%
dataset = pd.read_csv("dataset_with_incorrect_answers.csv")

# %%
def compare_outputs(row):

    output = str(row["Output"])
    incorrect_output = str(row["IncorrectOutput"])
    
    similarity_ratio = SequenceMatcher(None, output, incorrect_output).ratio()
    return similarity_ratio

def find_identical_rows(dataset):

    identical_rows = dataset[dataset["Output"] == dataset["IncorrectOutput"]]
    identical_rows = identical_rows.reset_index(drop=True)
    
    if not identical_rows.empty:
        print("\nRiadky, kde Output a IncorrectOutput sú rovnaké:")
        print(identical_rows[["Instruction", "Input", "Output", "Category", "Subcategory", "IncorrectOutput"]])
    else:
        print("\nNeboli nájdené žiadne riadky, kde Output a IncorrectOutput sú rovnaké.")

# %%
dataset["Similarity"] = dataset.apply(compare_outputs, axis=1)

find_identical_rows(dataset)

if os.path.exists("dataset_with_similarity.csv"):
    os.remove("dataset_with_similarity.csv")
    print("Starý súbor 'dataset_with_similarity.csv' bol odstránený.")
output_file = "dataset_with_similarity.csv"
dataset.to_csv(output_file, index=False)
print(f"Dataset s podobnosťou bol uložený do súboru: {output_file}")
# Out:
# Riadky, kde Output a IncorrectOutput sú rovnaké:
#                                             Instruction  \
# 0     Write a function to calculate the total number...
# 1     Write a Python program to generate a Fibonacci...
# 2     Design a Python function to calculate the area...
# 3     Develop an algorithm in Python to find the dep...
# 4     Write a function to sort a list of tuples usin...
# ...                                                 ...
# 2415  Generate a Python program that reads a line fr...
# 2416  Debug the following python code to make the co...
# 2417  Edit the following Python code to re-rank the ...
# 2418  Generate a python function that takes a list o...
# 2419  Write a Python program to count words in a sen...
#
#                                                   Input  \
# 0                                                   NaN
# 1                               Number of elements = 10
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2415                                                NaN
# 2416  x = "Hello World"\nif x == "Hello World:\nprin...
# 2417                             numbers = [4, 7, 2, 3]
# 2418  words = ['hello', 'world', 'this', 'is', 'a', ...
# 2419  Sentence: “The quick brown fox jumps over the ...
#
#                                                  Output  \
# 0     from datetime import datetime\n\ndef calculate...
# 1     def generateFibonacci(numOfElements):\n sequen...
# 2     def area_of_circle(radius):\n    return math.p...
# 3     def findDepth(root): \n    if root is None: \n...
# 4     def subject_marks(subjectmarks):\r\n#subject_m...
# ...                                                 ...
# 2415  def count_words():\n    sentence = input("Plea...
# 2416  x = "Hello World"\nif x == "Hello World":\n   ...
# 2417  numbers = [4, 7, 2, 3]\nnumbers.sort(reverse=T...
# 2418  def longest_string(words):\n    longest = 0\n ...
# 2419  sentence = "The quick brown fox jumps over the...
#
#                                 Category Subcategory  \
# 0                            Mathematics   calculate
# 1     Algorithms and Dynamic Programming   fibonacci
# 2                            Mathematics   calculate
# 3                        Data Structures        tree
# 4                                Sorting        sort
# ...                                  ...         ...
# 2415                       File Handling        read
# 2416               Testing and Debugging       debug
# 2417                         Mathematics      number
# 2418                     Data Structures        list
# 2419                     Data Structures  dictionary
#
#                                         IncorrectOutput
# 0     from datetime import datetime\n\ndef calculate...
# 1     def generateFibonacci(numOfElements):\n sequen...
# 2     def area_of_circle(radius):\n    return math.p...
# 3     def findDepth(root): \n    if root is None: \n...
# 4     def subject_marks(subjectmarks):\r\n#subject_m...
# ...                                                 ...
# 2415  def count_words():\n    sentence = input("Plea...
# 2416  x = "Hello World"\nif x == "Hello World":\n   ...
# 2417  numbers = [4, 7, 2, 3]\nnumbers.sort(reverse=T...
# 2418  def longest_string(words):\n    longest = 0\n ...
# 2419  sentence = "The quick brown fox jumps over the...
#
# [2420 rows x 6 columns]
# Starý súbor 'dataset_with_similarity.csv' bol odstránený.
# Dataset s podobnosťou bol uložený do súboru: dataset_with_similarity.csv

# %%
# Počet otázok, kde Similarity == 1
similar_questions_count = dataset[dataset["Similarity"] == 1].shape[0]

print(f"Počet otázok so Similarity == 1: {similar_questions_count}")
# Out:
# Počet otázok so Similarity == 1: 2420

# %%
similar_rows = dataset[dataset["Similarity"] == 1]
# Počet jedinečných podskupín (Subcategory)
unique_subcategories_count = similar_rows["Subcategory"].nunique()

print(f"Počet jedinečných podskupín so Similarity == 1: {unique_subcategories_count}")
# Out:
# Počet jedinečných podskupín so Similarity == 1: 56

# %%
unique_subcategories = similar_rows["Subcategory"].unique()
print("Jedinečné podskupiny so Similarity == 1:")
print(unique_subcategories)
# Out:
# Jedinečné podskupiny so Similarity == 1:
# ['calculate' 'fibonacci' 'tree' 'sort' 'list' 'sum' 'number' 'lambda'
#  'variable' 'mean' 'parameter' 'array' 'dictionary' 'continue' 'read'
#  'for loop' 'print' 'sorting' 'while' 'linked list' 'date' 'set'
#  'generator' 'decision' 'multiply' 'duplicate' 'error' 'exception'
#  'histogram' 'case' 'loop' 'if' 'dataframe' 'debug' 'quick sort' 'file'
#  'plot' 'matplotlib' 'prime' 'open' 'numpy' 'median' 'csv' 'analysis'
#  'xml' 'try' 'visualization' 'data type' 'calculator' 'queue' 'close'
#  'boolean' 'optimization' 'condition' 'stack' 'distribution']

# %%
data_s = pd.read_csv("dataset_with_similarity.csv")
data_c = pd.read_csv("dataset_with_incorrect_answers.csv")

# %%
similar_questions = data_s[data_s["Similarity"] == 1]

# Odstránenie otázok z data_c, ktoré sú v similar_questions
# Porovnáva sa na základe 'Instruction' a 'Input'
filtered_data = data_c[~data_c[["Instruction", "Input"]].apply(
    tuple, axis=1).isin(similar_questions[["Instruction", "Input"]].apply(tuple, axis=1))]

if os.path.exists("final_dataset.csv"):
    os.remove("final_dataset.csv")
    print("Starý súbor 'final_dataset.csv' bol odstránený.")
output_file = "final_dataset.csv"
filtered_data.to_csv(output_file, index=False)
print(f"Upravený dataset bol uložený do súboru: {output_file}")
# Out:
# Starý súbor 'final_dataset.csv' bol odstránený.
# Upravený dataset bol uložený do súboru: final_dataset.csv

# %% [markdown]
# Analýza FINAL_DATASET

# %%
vysledny_dataset = pd.read_csv("final_dataset.csv")

# %%
vysledny_dataset
# Out:
#                                             Instruction  \
# 0     Write a function to find squares of individual...
# 1     Create a function in Python which takes a list...
# 2     Design a function in Python that sorts a list ...
# 3     Develop a greedy strategy in Python to find th...
# 4     GPT-model, create a Python program for shuffel...
# ...                                                 ...
# 8328  Generate a new Python list with the squared va...
# 8329  Write a python program that creates and prints...
# 8330  Create a web scraper in Python that loads a we...
# 8331  Design an algorithm in Python for finding and ...
# 8332  Write a python program to print the following ...
#
#                                                   Input  \
# 0                                                   NaN
# 1                                             [3, 4, 5]
# 2                            ['red', 'green', 'orange']
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8328                          list = [1, 2, 3, 4, 5, 6]
# 8329         Start from 0, increment by 2 and end at 10
# 8330  URL: https://www.example.com/\nText to extract...
# 8331                                                100
# 8332                                              n = 5
#
#                                                  Output              Category  \
# 0     def square_nums(nums):\r\n square_nums = list(...       Data Structures
# 1     def sum_squares(nums):\n    result = 0\n    fo...       Data Structures
# 2     def sort_list_alphabetically(input_list): \n  ...               Sorting
# 3     def min_cost(points):\n    points.sort()  # so...           Mathematics
# 4     import random\n\ndef shuffle(arr):\n  for i in...  Scientific Computing
# ...                                                 ...                   ...
# 8328  def squared_list(list):\n    squared_list = []...       Data Structures
# 8329  for number in range(0, 11, 2):\n    print(number)                Syntax
# 8330  import requests\nfrom bs4 import BeautifulSoup...       Data Structures
# 8331  def find_all_primes(n): \n  for num in range(2...           Mathematics
# 8332  def pattern(n):\n  # Outer loop \n    for i in...                Syntax
#
#      Subcategory                                    IncorrectOutput
# 0           list  def square_nums(nums)\r\n square_nums = list(m...
# 1           list  define sum_squares(nums):\n    result = 0\n   ...
# 2           sort  def sort_list_alphabetically(input_list): \n  ...
# 3         number  def min_cost(points):\n    points.sort()  # so...
# 4          array  import random\n\ndef shuffle(arr)\n  for i in ...
# ...          ...                                                ...
# 8328        list  def squared_lst(list):\n    squared_list = []\...
# 8329       print  for number in range(0, 11, 2):\n    priteger(n...
# 8330      string  import requests\nfrom bs4 import BeautifulSoup...
# 8331       prime  def find_all_primes(n): \n  for num in range(2...
# 8332       print  def pattern(n):\n  # Outer loop \n    for i in...
#
# [8333 rows x 6 columns]

# %%
categories = vysledny_dataset["Category"].value_counts()
categories
# Out:
# Category
# Data Structures                       2644
# Mathematics                           1596
# Syntax                                1153
# Scientific Computing                   978
# Object-Oriented Programming            703
# Branching                              429
# Sorting                                352
# Loops                                  137
# Algorithms and Dynamic Programming     110
# Functions and Advanced Concepts         78
# File Handling                           63
# Testing and Debugging                   53
# Data Analysis                           37
# Name: count, dtype: int64

# %%
vysledny_dataset["Subcategory"].unique()
# Out:
# array(['list', 'sort', 'number', 'array', 'print', 'calculator',
#        'parameter', 'if', 'calculate', 'string', 'elif', 'stack',
#        'data structure', 'class', 'read', 'fibonacci', 'integer',
#        'dictionary', 'volume', 'user input', 'nested loop', 'random',
#        'average', 'multiply', 'sum', 'sorting', 'loop', 'temperature',
#        'tree', 'error', 'object', 'matrix', 'date', 'tuple', 'prime',
#        'median', 'try/except', 'euclidean algorithm', 'duplicate',
#        'quicksort algorithm', 'set', 'optimization', 'distribution',
#        'pandas', 'lambda', 'memoization', 'hash table', 'decorator',
#        'for loop', 'for each', 'boolean', 'numpy', 'case', 'file', 'max',
#        'linked list', 'mean', 'while', 'unit test', 'generator',
#        'decision', 'queue', 'open', 'quick sort', 'condition', 'operator',
#        'variable', 'histogram', 'debug', 'min', 'pi', 'close', 'axis',
#        'visualization', 'xml', 'matplotlib', 'data type', 'float', 'std',
#        'validation', 'try', 'dataframe', 'exception', 'algebra', 'csv',
#        'statistic', 'switch', 'break', 'plot', 'catch', 'knapsack'],
#       dtype=object)

# %%
count_subcategory = vysledny_dataset["Subcategory"].value_counts()

print("Počet otázok v jednotlivých podkategóriách:")
for subcategory, count in count_subcategory.items():
    print(f"{subcategory}: {count} otázok")
# Out:
# Počet otázok v jednotlivých podkategóriách:
# string: 1341 otázok
# list: 938 otázok
# number: 737 otázok
# print: 660 otázok
# class: 636 otázok
# calculate: 472 otázok
# random: 420 otázok
# array: 403 otázok
# if: 330 otázok
# sort: 286 otázok
# sum: 207 otázok
# integer: 178 otázok
# dictionary: 168 otázok
# set: 111 otázok
# duplicate: 98 otázok
# tuple: 83 otázok
# fibonacci: 81 otázok
# loop: 75 otázok
# elif: 70 otázok
# object: 67 otázok
# average: 58 otázok
# sorting: 58 otázok
# data structure: 57 otázok
# temperature: 55 otázok
# prime: 53 otázok
# for loop: 47 otázok
# pandas: 44 otázok
# matrix: 43 otázok
# date: 42 otázok
# read: 42 otázok
# parameter: 41 otázok
# user input: 40 otázok
# error: 23 otázok
# multiply: 22 otázok
# stack: 21 otázok
# tree: 18 otázok
# case: 17 otázok
# lambda: 17 otázok
# median: 16 otázok
# optimization: 16 otázok
# generator: 15 otázok
# mean: 13 otázok
# variable: 12 otázok
# calculator: 12 otázok
# volume: 10 otázok
# quicksort algorithm: 9 otázok
# debug: 9 otázok
# file: 9 otázok
# quick sort: 8 otázok
# exception: 8 otázok
# while: 8 otázok
# float: 7 otázok
# queue: 7 otázok
# pi: 7 otázok
# numpy: 6 otázok
# dataframe: 6 otázok
# linked list: 6 otázok
# unit test: 5 otázok
# max: 5 otázok
# histogram: 5 otázok
# xml: 5 otázok
# decorator: 5 otázok
# hash table: 5 otázok
# condition: 5 otázok
# std: 4 otázok
# distribution: 4 otázok
# try/except: 4 otázok
# decision: 4 otázok
# switch: 3 otázok
# csv: 3 otázok
# close: 3 otázok
# for each: 3 otázok
# visualization: 3 otázok
# break: 2 otázok
# try: 2 otázok
# data type: 2 otázok
# memoization: 2 otázok
# operator: 2 otázok
# nested loop: 2 otázok
# matplotlib: 1 otázok
# axis: 1 otázok
# validation: 1 otázok
# min: 1 otázok
# open: 1 otázok
# algebra: 1 otázok
# boolean: 1 otázok
# statistic: 1 otázok
# euclidean algorithm: 1 otázok
# plot: 1 otázok
# catch: 1 otázok
# knapsack: 1 otázok

# %%
def count_nonempty_lines(output_text):
    if pd.isna(output_text):
        return 0
    return sum(1 for line in output_text.split('\n') if line.strip())

def create_line_count_distribution(dataset):
    # Spočítanie neprázdnych riadkov pre každú odpoveď
    line_counts = dataset['Output'].apply(count_nonempty_lines)
    distribution = Counter(line_counts)
    
    plt.figure(figsize=(10, 6))
    plt.bar(distribution.keys(), distribution.values(), width=0.8)
    plt.title("Distribúcia odpovedí podľa počtu neprázdnych riadkov")
    plt.xlabel("Počet neprázdnych riadkov v odpovedi")
    plt.ylabel("Počet výskytov")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
    
    return distribution

distribution = create_line_count_distribution(vysledny_dataset)
print("Distribúcia výskytov odpovedí podľa počtu neprázdnych riadkov:")
for line_count, count in sorted(distribution.items()):
    print(f"{line_count} riadkov: {count} odpovedí")
# Out:
# Distribúcia výskytov odpovedí podľa počtu neprázdnych riadkov:
# 1 riadkov: 125 odpovedí
# 2 riadkov: 555 odpovedí
# 3 riadkov: 708 odpovedí
# 4 riadkov: 666 odpovedí
# 5 riadkov: 996 odpovedí
# 6 riadkov: 928 odpovedí
# 7 riadkov: 959 odpovedí
# 8 riadkov: 912 odpovedí
# 9 riadkov: 729 odpovedí
# 10 riadkov: 538 odpovedí
# 11 riadkov: 443 odpovedí
# 12 riadkov: 337 odpovedí
# 13 riadkov: 218 odpovedí
# 14 riadkov: 138 odpovedí
# 15 riadkov: 81 odpovedí
